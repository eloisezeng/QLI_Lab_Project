# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd drive/MyDrive/QLI_Lab_Project/video_processing
# Out:
# /content/drive/MyDrive/QLI_Lab_Project/video_processing

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np
import time
import pandas as pd

# %%
# for each layered image
    # graph the scattered light intensities w/ x-axis as pixel column number or angle
# Compare with simulations

thetas = [0, 10, 20, 30, 40, 50, 120, 130, 140, 150, 160, 170, 175, 176, 177, 178, 179]
def plot_scattered_light(seconds, fps=24):
    """Plot and save graphs"""
    fig, ax = plt.subplots(6, 3, figsize=(15, 15))
    fig.tight_layout(pad=3)
    idx = 0
    theta = thetas[idx]
    for i in range(0, 6):
        for j in range(0, 3):
            if idx < len(thetas):
                theta = thetas[idx]
                hists = np.load(f'hists/theta_{theta}_hists.npy')
                ax[i, j].scatter(np.arange(hists.shape[1]), np.sum(hists[:fps * seconds, :], axis=0), s=1)
                # ax[i][j].set_yticks([0, 200, 400, 600, 765])
                # ax[i][j].set_ylim(0, 770)
                ax[i][j].set_xlabel(f'Column #, theta_L={theta}º, time={seconds} s')
                ax[i][j].set_ylabel("Light Intensity")
            idx += 1
    plt.savefig(f'scattered_light_intensity_graphs/time_{seconds}') # save plot as .png file
    plt.show()

# %%
plot_scattered_light(1)

# %%
plot_scattered_light(3)

# %%
plot_scattered_light(5)

# %%
plot_scattered_light(10)

# %%
plot_scattered_light(30)

# %%
plot_scattered_light(60)
